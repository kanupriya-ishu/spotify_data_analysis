# %% [markdown]
# <a href="https://colab.research.google.com/github/kanupriya-ishu/spotify_data_analysis/blob/main/spotify_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_tracks = pd.read_csv('dataset/tracks.csv')
df_tracks.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve         6.0
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista         0.0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado         0.0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado         0.0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening         0.0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0     126903.0       0.0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1      98200.0       0.0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2     181640.0       0.0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3     176907.0       0.0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4     163080.0       0.0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1922-02-22         0.645  0.4450  0.0   -13.338   1.0       0.4510
# 1   1922-06-01         0.695  0.2630  0.0   -22.136   1.0       0.9570
# 2   1922-03-21         0.434  0.1770  1.0   -21.180   1.0       0.0512
# 3   1922-03-21         0.321  0.0946  7.0   -27.961   1.0       0.0504
# 4         1922         0.402  0.1580  3.0   -16.900   0.0       0.0390
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674            0.7440     0.151    0.127  104.851             3.0
# 1         0.797            0.0000     0.148    0.655  102.009             1.0
# 2         0.994            0.0218     0.212    0.457  130.418             5.0
# 3         0.995            0.9180     0.104    0.397  169.980             3.0
# 4         0.989            0.1300     0.311    0.196  103.220             4.0

# %%
pd.isnull(df_tracks).sum()
# Out:
# id                  0
# name                1
# popularity          1
# duration_ms         1
# explicit            1
# artists             1
# id_artists          1
# release_date        1
# danceability        1
# energy              1
# key                 1
# loudness            1
# mode                1
# speechiness         1
# acousticness        1
# instrumentalness    1
# liveness            1
# valence             1
# tempo               1
# time_signature      1
# dtype: int64

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356677 entries, 0 to 356676
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                356677 non-null  object
#  1   name              356676 non-null  object
#  2   popularity        356676 non-null  float64
#  3   duration_ms       356676 non-null  float64
#  4   explicit          356676 non-null  float64
#  5   artists           356676 non-null  object
#  6   id_artists        356676 non-null  object
#  7   release_date      356676 non-null  object
#  8   danceability      356676 non-null  float64
#  9   energy            356676 non-null  float64
#  10  key               356676 non-null  float64
#  11  loudness          356676 non-null  float64
#  12  mode              356676 non-null  float64
#  13  speechiness       356676 non-null  float64
#  14  acousticness      356676 non-null  float64
#  15  instrumentalness  356676 non-null  float64
#  16  liveness          356676 non-null  float64
#  17  valence           356676 non-null  float64
#  18  tempo             356676 non-null  float64
#  19  time_signature    356676 non-null  float64
# dtypes: float64(15), object(5)
# memory usage: 54.4+ MB

# %%
sorted_df = df_tracks.sort_values('popularity', ascending = True).head(10)
sorted_df
# Out:
#                             id  \
# 26060   01x6XlIfB1XHhV14mxXt1p
# 135670  3CPAOkUrdI2KAI64Plk8js
# 86982   6nuHpUh1HP2LYSzZMCMXy2
# 135669  3BYrVY1SHGnHg8l6OM6aCx
# 135668  3BHSnwR8Zys0zkdF3o2fts
# 106983  7ILuZZjTjy3qhZLqzQla9Q
# 135667  37leyrpNgvzoOYE3w2deAc
# 124046  13ffoMvaYKL4MkFfR7Xpdb
# 135666  36wurRaVSyM7IA8XreRxgT
# 124045  13VC5iEAk6tmBG9sZKWqAV
#
#                                                      name  popularity  \
# 26060                         Aa Gai Jinko Dekh Sharmaoon         0.0
# 135670                                   For Dancers Only         0.0
# 86982                             1000 Years - BARE Remix         0.0
# 135669                           When the Spirit Moves Me         0.0
# 135668                                 I Used to Love You         0.0
# 106983                                           Me Gusta         0.0
# 135667                              I'm Gonna See My Baby         0.0
# 124046  Passover Seder Festival: A Passover Service: M...         0.0
# 135666                                         Surrealism         0.0
# 124045  Welcoming the Sabbath - A Friday Evening Servi...         0.0
#
#         duration_ms  explicit                               artists  \
# 26060      187147.0       0.0                           ['Suraiya']
# 135670     151872.0       0.0                  ['Jimmie Lunceford']
# 86982      180004.0       0.0                         ['Gina Star']
# 135669     141162.0       0.0                    ['Charlie Barnet']
# 135668     170262.0       0.0                  ['Jimmie Lunceford']
# 106983     386693.0       0.0       ['Underground Sound Of Lisbon']
# 135667     183950.0       0.0                  ['Jimmie Lunceford']
# 124046     187960.0       0.0  ['Sholom Secunda', 'Richard Tucker']
# 135666     168120.0       0.0                    ['Charlie Barnet']
# 124045     320827.0       0.0  ['Sholom Secunda', 'Richard Tucker']
#
#                                                id_artists release_date  \
# 26060                          ['71lk7UDkZK1mabUE6LCASW']   1952-01-01
# 135670                         ['5z49AOW1q5dtslkcj6wGsW']         1939
# 86982                          ['6wHb8gl20vNhakwMKrp1bv']   2013-10-06
# 135669                         ['4SPws2VXOmZIiRTp75mzsb']         1939
# 135668                         ['5z49AOW1q5dtslkcj6wGsW']         1939
# 106983                         ['1KLufL4OUQFuzqaD3hSQ5u']   1998-02-26
# 135667                         ['5z49AOW1q5dtslkcj6wGsW']         1939
# 124046  ['02vrqtPq7oaIuwb3huM5Hx', '6BRN7IxoTswNo5rYYZ...         1950
# 135666                         ['4SPws2VXOmZIiRTp75mzsb']         1939
# 124045  ['02vrqtPq7oaIuwb3huM5Hx', '6BRN7IxoTswNo5rYYZ...         1950
#
#         danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 26060          0.521   0.236   8.0    -8.073   1.0       0.2160      0.982000
# 135670         0.585   0.792   8.0    -2.721   1.0       0.0545      0.791000
# 86982          0.705   0.973   6.0     1.027   0.0       0.1760      0.004340
# 135669         0.568   0.494   5.0    -3.004   1.0       0.0586      0.960000
# 135668         0.527   0.676   5.0    -3.584   1.0       0.0673      0.977000
# 106983         0.839   0.820  10.0   -11.815   0.0       0.1280      0.000439
# 135667         0.636   0.752   7.0    -2.536   1.0       0.0692      0.933000
# 124046         0.450   0.238   5.0   -12.220   1.0       0.0481      0.986000
# 135666         0.371   0.501   0.0   -10.906   0.0       0.0811      0.995000
# 124045         0.212   0.307  10.0   -11.985   1.0       0.0467      0.909000
#
#         instrumentalness  liveness  valence    tempo  time_signature
# 26060           0.000017    0.1110    0.837   63.669             3.0
# 135670          0.466000    0.0549    0.962  168.309             4.0
# 86982           0.039400    0.3300    0.561  144.002             4.0
# 135669          0.016600    0.0776    0.955  176.687             4.0
# 135668          0.115000    0.3240    0.741  200.463             4.0
# 106983          0.840000    0.2730    0.454  122.006             4.0
# 135667          0.004540    0.2390    0.486  146.285             4.0
# 124046          0.000006    0.0784    0.311  110.803             4.0
# 135666          0.922000    0.2570    0.665  179.208             4.0
# 124045          0.000133    0.2340    0.141  173.533             4.0

# %%
df_tracks.describe().transpose()
# Out:
#                      count           mean            std     min  \
# popularity        356676.0      27.434467      19.626378     0.0
# duration_ms       356676.0  229323.315014  126107.260315  3344.0
# explicit          356676.0       0.039120       0.193880     0.0
# danceability      356676.0       0.560091       0.167558     0.0
# energy            356676.0       0.527038       0.255239     0.0
# key               356676.0       5.209509       3.519679     0.0
# loudness          356676.0     -10.505804       5.191245   -60.0
# mode              356676.0       0.670062       0.470191     0.0
# speechiness       356676.0       0.095929       0.165572     0.0
# acousticness      356676.0       0.463287       0.353768     0.0
# instrumentalness  356676.0       0.128466       0.281574     0.0
# liveness          356676.0       0.209054       0.181266     0.0
# valence           356676.0       0.551668       0.262099     0.0
# tempo             356676.0     118.385232      29.763889     0.0
# time_signature    356676.0       3.875071       0.466674     0.0
#
#                            25%            50%          75%          max
# popularity            10.00000      27.000000      41.0000      100.000
# duration_ms       173160.00000  212425.000000  261400.0000  5621218.000
# explicit               0.00000       0.000000       0.0000        1.000
# danceability           0.44900       0.574000       0.6830        0.988
# energy                 0.32200       0.531000       0.7360        1.000
# key                    2.00000       5.000000       8.0000       11.000
# loudness             -13.24400      -9.563000      -6.6860        5.109
# mode                   0.00000       1.000000       1.0000        1.000
# speechiness            0.03390       0.043500       0.0711        0.971
# acousticness           0.10200       0.447000       0.8070        0.996
# instrumentalness       0.00000       0.000044       0.0197        1.000
# liveness               0.09740       0.136000       0.2670        1.000
# valence                0.34000       0.564000       0.7750        1.000
# tempo                 95.72575     117.073000     136.0870      243.507
# time_signature         4.00000       4.000000       4.0000        5.000

# %%
most_popular = df_tracks.query('popularity>90', inplace=False).sort_values('popularity', ascending=False)
most_popular[:10]
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 92810  5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 92811  6tDDoYIxWvMLTdKpjFkc1B                               telepatía
# 92813  0VjIjW4GlUZAMYd2vXMi3b                         Blinding Lights
# 93805  7MAibcTli4IisCtbHKrGMh                     Leave The Door Open
# 92814  6f3Slt0GbA2bPZlz0aIFXN                            The Business
# 91866  60ynsPSSKe6O3sfwRnIBRf                                 Streets
# 92816  3FAJ6O0NOHQV8Mc5Ri6ENp                  Heartbreak Anniversary
#
#        popularity  duration_ms  explicit  \
# 93802       100.0     198082.0       1.0
# 93803        99.0     242014.0       1.0
# 93804        98.0     132780.0       0.0
# 92810        97.0     215627.0       1.0
# 92811        97.0     160191.0       0.0
# 92813        96.0     200040.0       0.0
# 93805        96.0     242096.0       0.0
# 92814        95.0     164000.0       0.0
# 91866        94.0     226987.0       1.0
# 92816        94.0     198371.0       0.0
#
#                                               artists  \
# 93802    ['Justin Bieber', 'Daniel Caesar', 'Giveon']
# 93803                              ['Olivia Rodrigo']
# 93804                                 ['Masked Wolf']
# 92810                                  ['The Weeknd']
# 92811                                  ['Kali Uchis']
# 92813                                  ['The Weeknd']
# 93805  ['Bruno Mars', 'Anderson .Paak', 'Silk Sonic']
# 92814                                      ['Tiësto']
# 91866                                    ['Doja Cat']
# 92816                                      ['Giveon']
#
#                                               id_artists release_date  \
# 93802  ['1uNFoZAHBGtllmzznpCI3s', '20wkVLutqVOYrc0kxF...   2021-03-19
# 93803                         ['1McMsnEElThX1knmY4oliG']   2021-01-08
# 93804                         ['1uU7g3DNSbsu0QjSEqZtEd']   2021-01-06
# 92810                         ['1Xyo4u8uXC1ZmMpatF05PJ']   2020-03-20
# 92811                         ['1U1el3k54VvEUzo3ybLPlM']   2020-12-04
# 92813                         ['1Xyo4u8uXC1ZmMpatF05PJ']   2020-03-20
# 93805  ['0du5cEVh5yTK9QJze8zA0C', '3jK9MiCrA42lLAdMGU...   2021-03-05
# 92814                         ['2o5jDhtHVPhrJdv3cEQ99Z']   2020-09-16
# 91866                         ['5cj0lLjcoR7YOSnhnX0Po5']   2019-11-07
# 92816                         ['4fxd5Ee7UefO4CUXgwJ7IP']   2020-03-27
#
#        danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 93802         0.677   0.696   0.0    -6.181   1.0       0.1190       0.32100
# 93803         0.585   0.436  10.0    -8.761   1.0       0.0601       0.72100
# 93804         0.778   0.695   4.0    -6.865   0.0       0.0913       0.17500
# 92810         0.680   0.826   0.0    -5.487   1.0       0.0309       0.02120
# 92811         0.653   0.524  11.0    -9.016   0.0       0.0502       0.11200
# 92813         0.514   0.730   1.0    -5.934   1.0       0.0598       0.00146
# 93805         0.586   0.616   5.0    -7.964   1.0       0.0324       0.18200
# 92814         0.798   0.620   8.0    -7.079   0.0       0.2320       0.41400
# 91866         0.749   0.463  11.0    -8.433   1.0       0.0828       0.20800
# 92816         0.449   0.465   0.0    -8.964   1.0       0.0791       0.52400
#
#        instrumentalness  liveness  valence    tempo  time_signature
# 93802          0.000000    0.4200    0.464   90.030             4.0
# 93803          0.000013    0.1050    0.132  143.874             4.0
# 93804          0.000000    0.1500    0.472  149.996             4.0
# 92810          0.000012    0.5430    0.644  118.051             4.0
# 92811          0.000000    0.2030    0.553   83.970             4.0
# 92813          0.000095    0.0897    0.334  171.005             4.0
# 93805          0.000000    0.0927    0.719  148.088             4.0
# 92814          0.019200    0.1120    0.235  120.031             4.0
# 91866          0.037100    0.3370    0.190   90.028             4.0
# 92816          0.000001    0.3030    0.543   89.087             3.0

# %%
df_tracks.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve         6.0
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista         0.0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado         0.0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado         0.0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening         0.0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0     126903.0       0.0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1      98200.0       0.0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2     181640.0       0.0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3     176907.0       0.0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4     163080.0       0.0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1922-02-22         0.645  0.4450  0.0   -13.338   1.0       0.4510
# 1   1922-06-01         0.695  0.2630  0.0   -22.136   1.0       0.9570
# 2   1922-03-21         0.434  0.1770  1.0   -21.180   1.0       0.0512
# 3   1922-03-21         0.321  0.0946  7.0   -27.961   1.0       0.0504
# 4         1922         0.402  0.1580  3.0   -16.900   0.0       0.0390
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674            0.7440     0.151    0.127  104.851             3.0
# 1         0.797            0.0000     0.148    0.655  102.009             1.0
# 2         0.994            0.0218     0.212    0.457  130.418             5.0
# 3         0.995            0.9180     0.104    0.397  169.980             3.0
# 4         0.989            0.1300     0.311    0.196  103.220             4.0
